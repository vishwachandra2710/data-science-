# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
ir=pd.read_csv(r"C:\Users\vishw\Downloads\27th - Project\27th - Project\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")

# %%
ir.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
ir=ir.drop(['Id'],axis=1)

# %%
ir.head(2)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
ir.columns=['sl','sw','pl','pw','species']

# %%
ir.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'species'], dtype='object')

# %%
ir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sl       150 non-null    float64
#  1   sw       150 non-null    float64
#  2   pl       150 non-null    float64
#  3   pw       150 non-null    float64
#  4   species  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
ir.species.value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
ir.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
ir.species.nunique()
# Out:
# 3

# %% [markdown]
# **2.Bar Plot :**
# Here the frequency of the observation is plotted.In this case we are plotting the frequency of the three species in the Iris Dataset

# %%
colors=(['red','black','blue'])
plt.bar(data=ir,x='species',color=colors,height=50)
plt.show()

# %% [markdown]
# **4. Joint plot: **
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
ir.columns
# Out:
# Index(['sl', 'sw', 'pl', 'pw', 'species'], dtype='object')

# %%
sns.jointplot(data=ir,x='sl',y='sw')
plt.show()

# %%
sns.jointplot(data=ir,x='sl',y='sw',kind="hist")
plt.show()

# %%
sns.jointplot(data=ir,x='sl',y='sw',kind="reg")
plt.show()

# %%
sns.jointplot(data=ir,x='sl',y='sw',kind="resid")
plt.show()

# %%
sns.jointplot(data=ir,x='sl',y='sw',kind="kde")
plt.show()

# %%
a=sns.FacetGrid(data=ir,hue='species',height=5)

# %%
a=a.map(plt.scatter,'sl','sw')
plt.show()

# %% [markdown]
# **6. Boxplot or Whisker plot**
# Box plot was was first introduced in year 1969 by Mathematician John Tukey.Box plot give a statical summary of the features being plotted.Top line represent the max value,top edge of box is third Quartile, middle edge represents the median,bottom edge represents the first quartile value.The bottom most line respresent the minimum value of the feature.The height of the box is called as Interquartile range.The black dots on the plot represent the outlier values in the data.

# %%
sns.boxplot(data=ir,x="species",y='sl')
plt.show()

# %%
ir.boxplot(by="species", figsize=(10, 10))
plt.show()

# %%
sns.stripplot(data=ir,x='species',y='sl',jitter=True,edgecolor='red',palette='dark')
plt.show()

# %% [markdown]
# **8. Combining Box and Strip Plots**

# %%
sns.boxplot(data=ir,x="species",y='sl')
sns.stripplot(data=ir,x='species',y='sl',jitter=True,edgecolor='red',palette='dark')
plt.show()

# %%
sns.violinplot(data=ir,x='species',y='pw')
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(12,12))
sns.violinplot(data=ir,x="species",y="pl",ax=axes[0,0])
sns.violinplot(data=ir,x="species",y="pw",ax=axes[0,1])
sns.violinplot(data=ir,x="species",y="sl",ax=axes[1,0])
sns.violinplot(data=ir,x="species",y="sw",ax=axes[1,1])
plt.show()

# %%
sns.pairplot(data=ir,kind='scatter')
plt.show()

# %%
sns.pairplot(data=ir,kind='scatter',hue="species")
plt.show()

# %%
numeric_ir = ir.select_dtypes(include=['float64', 'int64'])

# %%
sns.heatmap(numeric_ir.corr(),annot=True,square=True)#,mask='False')#,#vmin=-1,vmax=1)
plt.show()

# %%
sns.histplot(data=ir)
plt.show()

# %%
ir.hist(edgecolor="red")
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(10,10)
sns.swarmplot(data=ir,x="species",y="sl")
plt.show()

# %%
sns.violinplot(data=ir,x="species",y="sl",hue="species",linewidth=2,linecolor="black",inner=None)
sns.swarmplot(data=ir,x="species",y="sl",color="white")
plt.show()

# %%
sns.lmplot(data=ir,x="pl",y="pw")#,hue="species")
plt.show()

# %%
sns.lmplot(data=ir,x="pl",y="pw",fit_reg=False)#,hue="species")
plt.show()

# %%
r=sns.FacetGrid(data=ir)#,hue="species")
r=r.map(sns.regplot,"pl","pw")
plt.show()

# %%
sns.catplot(data=ir,x='species',y='sl',kind="point")
plt.ioff()
plt.show()

# %%
sns.boxenplot(x='species',y='sl',data=ir,hue="species")
plt.show()

# %%
s=ir[ir['species']=='Iris-setosa']
sns.kdeplot(data=s[['sl','sw']], shade=True, shade_lowest=False)
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(10,5))
sns.boxplot(data=ir,x="species",y="sl",ax=axes[0])
sns.violinplot(data=ir,x="species",y="sl",ax=axes[1])
plt.show()

# %%
sns.histplot(data=ir, x="sl", hue="species", multiple="stack",bins=30)
plt.show()

# %%
ir.plot.area(y=['sl','sw','pl','pw'],figsize=(10,10),alpha=0.4)
plt.show()

# %%
sns.distplot(ir.sl)
plt.show()

# %%
sns.displot(ir.pl,bins=15,color='red')
plt.show()
