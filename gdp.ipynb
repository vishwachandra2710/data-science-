# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df = pd.read_csv(r"C:\Users\vishw\Downloads\data.csv")

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.shape
# Out:
# (195, 5)

# %%
len(df)
# Out:
# 195

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
catergical_data=df[['CountryName', 'CountryCode', 'IncomeGroup']]

# %%
catergical_data
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
numerical_data =df[['BirthRate', 'InternetUsers']]

# %%
numerical_data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
catergical_data.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
catergical_data.describe().T
# Out:
#             count unique          top freq
# CountryName   195    195        Aruba    1
# CountryCode   195    195          ABW    1
# IncomeGroup   195      4  High income   67

# %%
catergical_data.head(2)
# Out:
#    CountryName CountryCode  IncomeGroup
# 0        Aruba         ABW  High income
# 1  Afghanistan         AFG   Low income

# %%
catergical_data.describe().head(2)
# Out:
#        CountryName CountryCode IncomeGroup
# count          195         195         195
# unique         195         195           4

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns = ['a','b','c','d','e']

# %%
df
# Out:
#                         a    b       c     d                    e
# 0                   Aruba  ABW  10.244  78.9          High income
# 1             Afghanistan  AFG  35.253   5.9           Low income
# 2                  Angola  AGO  45.985  19.1  Upper middle income
# 3                 Albania  ALB  12.877  57.2  Upper middle income
# 4    United Arab Emirates  ARE  11.044  88.0          High income
# ..                    ...  ...     ...   ...                  ...
# 190           Yemen, Rep.  YEM  32.947  20.0  Lower middle income
# 191          South Africa  ZAF  20.850  46.5  Upper middle income
# 192      Congo, Dem. Rep.  COD  42.394   2.2           Low income
# 193                Zambia  ZMB  40.471  15.4  Lower middle income
# 194              Zimbabwe  ZWE  35.715  18.5           Low income
#
# [195 rows x 5 columns]

# %%
df.columns = ['CountryName', 'CountryCode','c','d','e']
df
# Out:
#               CountryName CountryCode       c     d                    e
# 0                   Aruba         ABW  10.244  78.9          High income
# 1             Afghanistan         AFG  35.253   5.9           Low income
# 2                  Angola         AGO  45.985  19.1  Upper middle income
# 3                 Albania         ALB  12.877  57.2  Upper middle income
# 4    United Arab Emirates         ARE  11.044  88.0          High income
# ..                    ...         ...     ...   ...                  ...
# 190           Yemen, Rep.         YEM  32.947  20.0  Lower middle income
# 191          South Africa         ZAF  20.850  46.5  Upper middle income
# 192      Congo, Dem. Rep.         COD  42.394   2.2           Low income
# 193                Zambia         ZMB  40.471  15.4  Lower middle income
# 194              Zimbabwe         ZWE  35.715  18.5           Low income
#
# [195 rows x 5 columns]

# %%
df.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup']

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df[23:25]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income

# %%
df[['CountryName','BirthRate']].tail()
# Out:
#           CountryName  BirthRate
# 190       Yemen, Rep.     32.947
# 191      South Africa     20.850
# 192  Congo, Dem. Rep.     42.394
# 193            Zambia     40.471
# 194          Zimbabwe     35.715

# %%
df[['BirthRate', 'InternetUsers',
       'IncomeGroup']][25:50:5]
# Out:
#     BirthRate  InternetUsers          IncomeGroup
# 25     12.188          73.00          High income
# 30     10.900          85.80          High income
# 35     37.236           6.40  Lower middle income
# 40     15.022          45.96  Upper middle income
# 45      8.500          84.17          High income

# %%
df[0:194:50][[ 'InternetUsers',
       'IncomeGroup']]
# Out:
#      InternetUsers          IncomeGroup
# 0        78.900000          High income
# 50       40.353684  Upper middle income
# 100      16.500000  Upper middle income
# 150      22.700000  Lower middle income

# %%
df.BirthRate * df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df['newcolumn']=df.BirthRate * df.InternetUsers

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'newcolumn'],
#       dtype='object')

# %%
df.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
#
#    newcolumn
# 0   808.2516
# 1   207.9927
# 2   878.3135

# %%
df=df.drop('newcolumn', axis =  1)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.columns[4]
# Out:
# 'IncomeGroup'

# %%
filter= df.InternetUsers < 23

# %%
filter
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192     True
# 193     True
# 194     True
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[filter]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 1         Afghanistan         AFG     35.253            5.9
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 13              Benin         BEN     36.440            4.9
# 14       Burkina Faso         BFA     40.551            9.1
# ..                ...         ...        ...            ...
# 189             Samoa         WSM     26.172           15.3
# 190       Yemen, Rep.         YEM     32.947           20.0
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 1             Low income
# 2    Upper middle income
# 11            Low income
# 13            Low income
# 14            Low income
# ..                   ...
# 189  Lower middle income
# 190  Lower middle income
# ...

# %%
filter2=df.BirthRate < 25

# %%
df[filter2]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244           78.9
# 3                           Albania         ALB     12.877           57.2
# 4              United Arab Emirates         ARE     11.044           88.0
# 5                         Argentina         ARG     17.716           59.9
# 6                           Armenia         ARM     13.308           41.9
# ..                              ...         ...        ...            ...
# 183  St. Vincent and the Grenadines         VCT     16.306           52.0
# 184                   Venezuela, RB         VEN     19.842           54.9
# 185           Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                         Vietnam         VNM     15.537           43.9
# 191                    South Africa         ZAF     20.850           46.5
#
#              IncomeGroup
# 0            High income
# 3    Upper middle income
# ...

# %%
filter & filter2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
df[(df.InternetUsers < 23) & (df.BirthRate < 25)]
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 15     Bangladesh         BGD     20.142           6.63  Lower middle income
# 49        Algeria         DZA     24.738          16.50  Upper middle income
# 75       Honduras         HND     21.593          17.80  Lower middle income
# 79      Indonesia         IDN     20.297          14.94  Lower middle income
# 80          India         IND     20.291          15.10  Lower middle income
# 93       Cambodia         KHM     24.462           6.80           Low income
# 100         Libya         LBY     21.425          16.50  Upper middle income
# 103     Sri Lanka         LKA     17.863          21.90  Lower middle income
# 117       Myanmar         MMR     18.119           1.60  Lower middle income
# 119      Mongolia         MNG     24.275          20.00  Upper middle income
# 129     Nicaragua         NIC     20.788          15.50  Lower middle income
# ...

# %%
df[df.InternetUsers > 90]
# Out:
#        CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 17         Bahrain         BHR      15.04       90.00004  High income
# 22         Bermuda         BMU      10.40       95.30000  High income
# 47         Denmark         DNK      10.00       94.62970  High income
# 56         Finland         FIN      10.70       91.51440  High income
# 84         Iceland         ISL      13.40       96.54680  High income
# 102  Liechtenstein         LIE       9.20       93.80000  High income
# 106     Luxembourg         LUX      11.30       93.77650  High income
# 130    Netherlands         NLD      10.20       93.95640  High income
# 131         Norway         NOR      11.60       95.05340  High income
# 163         Sweden         SWE      11.80       94.78360  High income

# %%
df[df.IncomeGroup == 'Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df.IncomeGroup.nunique()
# Out:
# 4

# %%
df.InternetUsers.unique()
# Out:
# array([78.9       ,  5.9       , 19.1       , 57.2       , 88.        ,
#        59.9       , 41.9       , 63.4       , 83.        , 80.6188    ,
#        58.7       ,  1.3       , 82.1702    ,  4.9       ,  9.1       ,
#         6.63      , 53.0615    , 90.0000397 , 72.        , 57.79      ,
#        54.17      , 33.6       , 95.3       , 36.94      , 51.04      ,
#        73.        , 64.5       , 29.9       , 15.        ,  3.5       ,
#        85.8       , 86.34      , 66.5       , 45.8       ,  8.4       ,
#         6.4       ,  6.6       , 51.7       ,  6.5       , 37.5       ,
#        45.96      , 27.93      , 74.1       , 65.4548    , 74.1104    ,
#        84.17      ,  9.5       , 94.6297    , 45.9       , 16.5       ,
#        40.35368423, 29.4       ,  0.9       , 71.635     , 79.4       ,
#         1.9       , 91.5144    , 37.1       , 81.9198    , 27.8       ,
#         9.2       , 89.8441    , 43.3       , 12.3       ,  1.6       ,
# ...

# %%
df.InternetUsers.nunique()
# Out:
# 181
