# %%
import pandas as pd

# %%
movies=pd.read_csv(r"C:\Users\vishw\Downloads\Movie-Rating.csv")

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.26.4'

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.isna().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['film', 'genre', 'criticratings', 'audienceratings','Budget', 'Year']

# %%
movies.head(1)
# Out:
#                     film   genre  criticratings  audienceratings  Budget  Year
# 0  (500) Days of Summer   Comedy             87               81       8  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   film             559 non-null    object
#  1   genre            559 non-null    object
#  2   criticratings    559 non-null    int64
#  3   audienceratings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['film']=movies['film'].astype('category')
movies['genre']=movies['genre'].astype('category')
#movies['year']=movies['year'].astype(str).astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   film             559 non-null    category
#  1   genre            559 non-null    category
#  2   criticratings    559 non-null    int64
#  3   audienceratings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
movies.columns
# Out:
# Index(['film', 'genre', 'criticratings', 'audienceratings', 'Budget', 'Year'], dtype='object')

# %%
movies['Year']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   film             559 non-null    category
#  1   genre            559 non-null    category
#  2   criticratings    559 non-null    int64
#  3   audienceratings  559 non-null    int64
#  4   Budget           559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.genre.nunique()
# Out:
# 7

# %%
movies.describe()
# Out:
#        criticratings  audienceratings      Budget
# count     559.000000       559.000000  559.000000
# mean       47.309481        58.744186   50.236136
# std        26.413091        16.826887   48.731817
# min         0.000000         0.000000    0.000000
# 25%        25.000000        47.000000   20.000000
# 50%        46.000000        58.000000   35.000000
# 75%        70.000000        72.000000   65.000000
# max        97.000000        96.000000  300.000000

# %%
movies.columns
# Out:
# Index(['film', 'genre', 'criticratings', 'audienceratings', 'Budget', 'Year'], dtype='object')

# %%
sns.jointplot(data=movies,y='audienceratings',x='criticratings')
plt.show()

# %%
sns.jointplot(data=movies,y='audienceratings',x='criticratings',kind='kde')
plt.show()

# %%
sns.jointplot(data=movies,y='audienceratings',x='criticratings',kind='hex')
plt.show()

# %%
sns.jointplot(data=movies,y='audienceratings',x='criticratings',kind='resid')
plt.show()

# %%
sns.jointplot(data=movies,y='audienceratings',x='criticratings',kind='hist')
plt.show()

# %%
sns.distplot(movies['Budget'])
plt.show()

# %%
sns.distplot(movies['Budget'],bins=10)
plt.show()

# %%
movies.Budget.mode()[0]
# Out:
# 20

# %%
sns.displot(movies['Budget'])
plt.show()

# %%
sns.displot(movies['Budget'],bins=10)
plt.show()

# %%
plt.hist(movies.Budget,bins=23)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
plt.hist(movies.Budget,bins=23)
plt.show()

# %%
plt.hist(movies[movies.genre =='Action'].Budget)
plt.show()

# %%
plt.hist(movies[movies.genre == 'Action'].Budget, bins = 15,label="action")
plt.hist(movies[movies.genre == 'Thriller'].Budget, bins = 20,label="thriller")
plt.hist(movies[movies.genre == 'Drama'].Budget, bins = 20,label="drama")
plt.legend()

plt.show()

# %%
plt.hist([movies[movies.genre == 'Action'].Budget,movies[movies.genre == 'Thriller'].Budget,
movies[movies.genre == 'Drama'].Budget],bins=20,label=["action","thriller","drama"],stacked=True)
plt.legend()

plt.show()

# %%
sns.lmplot(data=movies,x='criticratings',y='audienceratings')
plt.show()

# %%
sns.set_style('dark')
movies.columns
# Out:
# Index(['film', 'genre', 'criticratings', 'audienceratings', 'Budget', 'Year'], dtype='object')

# %%
sns.lmplot(data=movies,x='criticratings',y='audienceratings',fit_reg=False,hue='Year')
plt.show()

# %%
sns.lmplot(data=movies,x='criticratings',y='audienceratings',fit_reg=False,hue='Year',height=10,aspect=1)
plt.show()

# %%
sns.set_style('ticks')
k1 = sns.kdeplot(x=movies.Budget,y=movies.audienceratings,shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
f, axes = plt.subplots(1,2)

k1 = sns.regplot(data=movies,x=movies.Budget,y=movies.audienceratings,ax=axes[0])
k2 = sns.regplot(data=movies,x=movies.Budget,y=movies.criticratings,ax=axes[1])
plt.show()

# %%
movies.columns
# Out:
# Index(['film', 'genre', 'criticratings', 'audienceratings', 'Budget', 'Year'], dtype='object')

# %%
sns.boxplot(data=movies, x='genre', y = 'criticratings')
plt.show()

# %%
sns.violinplot(data=movies, x='genre', y = 'criticratings')
plt.show()

# %%
sns.boxplot(data=movies[movies.genre=='Action'],x="Year",y='criticratings')
plt.show()

# %%
t=sns.FacetGrid(data=movies,row="genre",col="Year")
plt.show(t)

# %%
t=t.map(plt.scatter,'criticratings','audienceratings')
plt.show()

# %%
i=sns.FacetGrid(data=movies,row='genre',col='Year')
i=i.map(plt.hist,'Budget')
plt.show(i)

# %%
t=sns.FacetGrid(data=movies,row="genre",col="Year",hue='genre')
kws=dict(s=50,edgecolor='red')
t=t.map(plt.scatter,'criticratings','audienceratings',**kws)
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15))
a=sns.regplot(data=movies,x='audienceratings',y='criticratings',ax=axes[0,0])
b=sns.kdeplot(data=movies,x='audienceratings',y='criticratings',cmap='cool',ax=axes[0,1])
c=sns.boxplot(data=movies[movies.genre=='Action'],x='genre',y='Year',ax=axes[1,0])
d=sns.distplot(movies.Year,ax=axes[1,1])
plt.show()
