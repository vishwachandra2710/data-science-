# %%
import matplotlib.pyplot as plt

# %%
matplotlib inline

# %%
import numpy as np

# %%
a=np.linspace(100,200,20)

# %%
plt.plot(a,np.sin(a))
plt.plot(a,np.cos(a))
plt.show()

# %%
plt.gcf()

# %%
plt.gca()
# Out:
# <Axes: >

# %%
plt.subplot(3,3,1)
plt.plot(a,np.sin(a))
plt.subplot(3,3,2)
plt.plot(a,np.cos(a))
plt.show()

# %%
plt.gcf()

# %%
plt.gca()
# Out:
# <Axes: >

# %%
y=([10,20,30,40,50])
plt.plot(y)
plt.show()

# %%
z=([1,4,9,16])
plt.plot(z)
plt.show()

# %% [markdown]
# linear quadratic cubic

# %%
r=np.linspace(1,10,100)
plt.plot(r,r,label="linear")
plt.plot(r,r**2,label="quadratic")
plt.plot(r,r**3,label="cubic")
plt.legend()
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,30,40],'ro')
plt.axis([0,5,0,40])
plt.show()

# %%
fig,ax=plt.subplots(2)
ax[0].plot(a,np.sin(a))
ax[1].plot(a,np.cos(a))
plt.show()

# %%
fig=plt.figure()
i=np.arange(10)
y=i**2
ax=fig.add_axes([0.3,0.5,0.3,0.5])
ax.plot(i,y)
plt.show()

# %%
fig=plt.figure()
ax=plt.axes()
plt.show()

# %%
plt.plot([1,4,3],'r')
plt.show()

# %%
e=range(5)
plt.plot(e,[i**2 for i in e])
plt.show()

# %% [markdown]
# scatter

# %%
plt.plot(a,np.tan(a),'ro')
plt.show()

# %%
j=([10,20,30,40,50,60])
plt.hist(j)#,bins=1000)
plt.show()

# %%
j=([10,20,30,40,50,60])
plt.hist(j,bins=15)
plt.show()

# %%
w=([10,20,30,40,50])
plt.bar(range(len(w)),(w))
plt.show()

# %%
y=range(10)
plt.barh(range(len(y)),(y))
plt.show()

# %%
r=([1,3,5,7,9])
t=np.exp(r)
e1=0.1*abs(t)
plt.errorbar(r,t,yerr=e1)
plt.show()

# %%
w=([1,2,3,4,5])
o=([2,3,4,6,8])
p=([1,2,3,4,5])
plt.bar(p,w,color='b')
plt.bar(p,o,color='r',bottom=w)
plt.show()

# %%
r=([25,25,40,2])
y=(['a','b','c','d'])
plt.pie(r,labels=y)
plt.show()

# %%
t=([23,45,67,89])
#r=([4.7,10,26,68])
plt.boxplot(t)
plt.show()

# %%
r=range(1,6)
y=([1,4,6,8,6])

# %%
plt.fill_between(r,y)

# %%
plt.show()

# %%
plt.stackplot(r,y)
plt.show()

# %%
#np.random.rand(10,3)
plt.contour(np.random.rand(10,3))
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-bright')

# %%
q=range(10)
r=range(10)
plt.plot(r,q)
plt.grid(True)
plt.show()

# %%
w=np.arange(1,5)
plt.plot(w,w,w,w**2,w,w**3)
plt.axis([0,10,0,10])
plt.show()

# %%
e=([2,4,6,8,10])
plt.plot(e)
plt.xlim([0,10])
plt.ylim([0,10])
plt.show()

# %%
r=([1,4,3])
plt.plot(r)
plt.xticks([1,2,3,4,5])
plt.yticks([2,4,6,8])
plt.show()

# %%
plt.plot([1,4,3])
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("this is graph")
plt.show()

# %%
t=np.arange(10)
r=t//2.0
y=t**2
plt.plot(t,label="abc")
plt.plot(r,label="cde")
plt.plot(y,label="rfv")
plt.legend()
plt.show()

# %%
t=np.arange(1,6)
plt.plot(t,ls=":",color='r')
plt.plot(t+1,ls="--",color='g')
plt.plot(t+2,ls="-.",color='b')
plt.show()
