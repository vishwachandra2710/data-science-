# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\vishw\Downloads\data.csv")

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
matplotlib inline

# %%
plt.rcParams['figure.figsize']= 8,4

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# distributions

# %%
v1=sns.distplot(df["InternetUsers"])  # singlevariate
plt.show()

# %%
v2=sns.distplot(df['BirthRate'])

# %%
plt.show()

# %%
v3=sns.distplot(df['InternetUsers'],bins=15)
plt.show()

# %%
v4=sns.displot(df['InternetUsers'])
plt.show()

# %%
v5=sns.displot(df['InternetUsers'],bins=7)
plt.show()

# %% [markdown]
# box plots multivariates

# %%
v6=sns.boxplot(data=df,x='IncomeGroup',y='BirthRate')
plt.show()

# %% [markdown]
# linearmodel

# %%
v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate")
plt.show()

# %%
v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False)
plt.show()

# %%
v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",hue="CountryCode",fit_reg=False)
plt.show()

# %%
v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",hue="IncomeGroup",fit_reg=False)
plt.show()

# %%
v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False,hue="IncomeGroup",size= 10 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 v7=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False,hue="IncomeGroup",size= 10 )
#       2 plt.show()
#
# TypeError: lmplot() got an unexpected keyword argument 'size'
